# %%
# !curl -sSL https://ngrok-agent.s3.amazonaws.com/ngrok.asc \
	| sudo tee /etc/apt/trusted.gpg.d/ngrok.asc >/dev/null \
	&& echo "deb https://ngrok-agent.s3.amazonaws.com buster main" \
	| sudo tee /etc/apt/sources.list.d/ngrok.list \
	&& sudo apt update \
	&& sudo apt install ngrok

# %%
# !ngrok config add-authtoken 2sFTraZVoMNYBNXGLRMfhFZNdF1_9AHKeLu2LezJ41YNdc9B

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
import subprocess
# process = subprocess.Popen("ollama serve", shell=True) #runs on a different thread
process = subprocess.Popen("OLLAMA_HOST=0.0.0.0 ollama serve", shell=True) #runs on a different thread
# !ollama pull llama3
# !ollama pull llama3.2
# !ollama pull deepseek-r1:32b
# !ollama pull deepseek-r1:14b
# !ollama pull deepseek-r1:8b
# !ollama pull deepseek-r1:7b
# !ollama pull deepseek-r1:1.5b

# %%
# ! OLLAMA_HOST=0.0.0.0 ollama serve

# %%
# !ngrok http --url=lab-rapid-yearly.ngrok-free.app 127.0.0.1:11434

# %%
input()
