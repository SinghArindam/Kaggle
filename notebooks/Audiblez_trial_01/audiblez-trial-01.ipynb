# %% [markdown]
# # Clone the repo and install the dependencies

# %%
# !rm -rf audiblez
# !git clone  https://github.com/santinic/audiblez
# !apt-get -y install espeak-ng ffmpeg libgtk-3-dev
# !cd audiblez && pip install poetry && poetry install

# %%
# !pip install audiblez

# %% [markdown]
# # Convert to audiobook

# %%
# !audiblez /kaggle/input/ebooks-epubs/sample_01.epub -v af_aoede --cuda

# %%
# !audiblez /kaggle/input/ebooks-epubs/sample_01.epub -v af_aoede

# %%
# !mkdir ./sample_01

# %%
# !cp sample_01*.* ./sample_01/

# %%
# !zip sample_01.zip ./sample_01/

# %%
# !audiblez /kaggle/input/ebooks-epubs/Reverend_Insanity.epub -v af_aoede --cuda

# %%
# !audiblez /kaggle/input/ebooks-epubs/Reverend_Insanity.epub -v af_aoede

# %%
# !mkdir ./Reverend_Insanity

# %%
# !cp Reverend_Insanity*.* ./Reverend_Insanity/

# %%
# !zip Reverend_Insanity.zip ./Reverend_Insanity/
